# %% [markdown]
# <a href="https://colab.research.google.com/github/PadmalokshanaM/Illegal-Entry-Detection-using-YOLOV8/blob/main/posdetectioncusdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov8" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [हिन्दी](https://docs.ultralytics.com/hi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov8"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
# Welcome to the Ultralytics YOLOv8 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLOv8</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLOv8 and understand its features and capabilities.
#
# YOLOv8 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of YOLOv8. Please browse the YOLOv8 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # 1. Setup
#
# Please open this file in Google Drive.
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.1/201.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# Connect your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.1/201.2 GB disk)
#
# OS                  Linux-6.1.58+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 50.99 GB
# CPU                 Intel Xeon 2.00GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.2.1+cu121>=1.8.0
# torchvision         ✅ 0.17.1+cu121>=0.9.0
# tqdm                ✅ 4.66.2>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 2.0.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0

# %% [markdown]
# Please follow the program requirements here to restart the session.Please do not restart the session immediately. Please wait for this part of the code to run successfully before restarting.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mB4ckDuxYhPL3ii9tscV")
project = rf.workspace("project-ptbeh").project("datasets-nbdxy")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.45, to fix: `pip install ultralytics==8.0.196`

# %%
import os
print(os.path.exists('/content/datasets-1/data.yaml'))
# Out:
# True

# %% [markdown]
# Normally there is no need to use it here. If the roboflow folder is not decompressed normally, you can use this to decompress it.

# %%
# import zipfile
# with zipfile.ZipFile('/content/datasets-1/roboflow.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/datasets-1')

# %% [markdown]
# # 2. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLOv8 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLOv8 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %% [markdown]
# The model used here is yolov8n. If you want to change the model, you can change it to yolov8s, yolov8m, yolov8l, or yolov8x.
# A necessary point: Please click the file icon on the left, data.yaml in datasets-1, and then modify
# test: ../test/images
# train: datasets-1/train/images
# val: datasets-1/valid/images
# for: test: ./test/images
# train: ./train/images
# val: ./valid/images

# %%
# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model

# Train the model
results = model.train(data="/content/datasets-1/data.yaml", imgsz=640, epochs=105, plots=True, conf=0.2)

# %% [markdown]
# # 3. Export
#
# Use the following command to export the YOLOv8 model.

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# Save content to your own Google Drive.

# %%
# %cp -r /content/runs/detect/train /content/drive/MyDrive/EXP/yolov8n-train

# %% [markdown]
# Show confusion matrix.

# %%
from IPython.display import display, Image
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)

# %% [markdown]
# Show training chart.

# %%
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %% [markdown]
# # 4. Python Usage
#
# YOLOv8 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLOv8 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLOv8 Python Docs](https://docs.ultralytics.com/usage/python/).

# %% [markdown]
# Perform model validation.

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

# It'll use the data yaml file in model.pt if you don't set data.
model.val(conf=0.4)
# or you can set the data you want to val
model.val(data="/content/datasets-1/data.yaml", conf=0.2)
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets-1/valid/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100%|██████████| 30/30 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 9, len(boxes) = 60. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.70it/s]
#                    all         30         60      0.821      0.694      0.777      0.517
#    Air-bubbles-trapped         30         17      0.917      0.647      0.799      0.432
#           Channel-loss         30          7       0.75      0.429      0.572      0.453
# ...

# %% [markdown]
# Make model predictions.

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
#/content/drive/MyDrive/EXP/photos/
results = model.predict(source="/content/",save=True)
# Out:
# image 1/2 /content/0092.jpg: 480x640 2 Contaminant-introduced-during-bondings, 1 Fractures-in-channel, 16.1ms
# image 2/2 /content/A0138.jpg: 480x640 1 Channel-loss, 8.8ms
# Speed: 3.3ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict5

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:8]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# %cp -r /content/runs/detect/ /content/drive/MyDrive/EXP/yolov8n-predict

# %% [markdown]
# # 5. Tasks
#
# Subsequent data processing is completed here. This part can be run independently after saving yolov8n-train.
# You can also unzip the EXP folder in GitHub, place it in the root directory of Google Drive, and then run this part directly.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install the ultralytics package using pip
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.7/744.7 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 70.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image

# %%
from IPython.display import Image

# %%
from PIL import Image
from ultralytics import YOLO

# Initialize your YOLO model (replace 'yolov8n.pt' with your model file)
my_new_model = YOLO('/content/drive/MyDrive/EXP/yolov8n-train/weights/best.pt')

# Load your image
new_image = '/content/drive/MyDrive/EXP/photos/02.jpg'

# Get predictions
new_results = my_new_model(new_image,show_labels=False,show_conf=False)

# Access bounding boxes (assuming new_results contains similar structure as 'results')
for r in new_results:
    im_array = r.plot()  # BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # Convert to RGB PIL image
    im.show_labels=False
    im.save('results2.jpg')  # save image
    im.show()  # Show image
    im.save('results1.jpg')  # save image
# Out:
# image 1/1 /content/drive/MyDrive/EXP/photos/02.jpg: 320x640 1 Air-bubbles-trapped, 1 Channel-loss, 1 Chip-alignment-errors, 1 Contaminant-introduced-during-bonding, 1 Contaminant-introduced-during-production, 1 Fractures-in-channel, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)

# %%
new_result_array = new_results[0].plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)

# %%
new_result = new_results[0]

# %%
new_result
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'Air-bubbles-trapped', 1: 'Channel-loss', 2: 'Chip-alignment-errors', 3: 'Contaminant-introduced-during-bonding', 4: 'Contaminant-introduced-during-production', 5: 'Fractures-in-channel'}
# obb: None
# orig_img: array([[[211, 211, 211],
#         [210, 210, 210],
#         [210, 210, 210],
#         ...,
#         [207, 207, 207],
#         [207, 207, 207],
#         [206, 206, 206]],
#
#        [[203, 203, 203],
#         [202, 202, 202],
#         [201, 201, 201],
#         ...,
#         [199, 199, 199],
#         [198, 198, 198],
#         [198, 198, 198]],
#
#        [[195, 195, 195],
#         [195, 195, 195],
#         [194, 194, 194],
#         ...,
#         [191, 191, 191],
#         [191, 191, 191],
#         [191, 191, 191]],
#
#        ...,
#
#        [[207, 207, 207],
#         [207, 207, 207],
# ...

# %%
class_names = new_result.names.values()
class_names
# Out:
# dict_values(['Air-bubbles-trapped', 'Channel-loss', 'Chip-alignment-errors', 'Contaminant-introduced-during-bonding', 'Contaminant-introduced-during-production', 'Fractures-in-channel'])

# %%
new_image = '/content/drive/MyDrive/EXP/02.jpg'

new_results = my_new_model.predict(new_image,save=True,show_labels=False)
new_results[0].boxes
new_result_array = new_results[0].plot()
print("new_results[0].boxes :")
for box in new_results[0].boxes:
    print(box)
# Out:
# image 1/1 /content/drive/MyDrive/EXP/02.jpg: 320x640 1 Air-bubbles-trapped, 1 Channel-loss, 1 Chip-alignment-errors, 1 Contaminant-introduced-during-bonding, 1 Contaminant-introduced-during-production, 1 Fractures-in-channel, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict3
# new_results[0].boxes :
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.8502], device='cuda:0')
# data: tensor([[1.6542e+03, 1.9142e+03, 2.0511e+03, 2.3481e+03, 8.5021e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (3072, 6144)
# shape: torch.Size([1, 6])
# xywh: tensor([[1852.6213, 2131.1099,  396.9287,  433.9061]], device='cuda:0')
# xywhn: tensor([[0.3015, 0.6937, 0.0646, 0.1412]], device='cuda:0')
# xyxy: tensor([[1654.1570, 1914.1569, 2051.0857, 2348.0630]], device='cuda:0')
# ...
